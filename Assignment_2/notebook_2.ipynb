# %%
import pandas as pd 
import numpy as nd

# %%
df=pd.read_csv('telecom_customer_churn.csv')

# %%
rowColumn = df.shape
print(f"Total number of rows and coloum: {rowColumn}")
# Out:
# Total number of rows and coloum: (6923, 38)

# %%
df
# Out:
#      Customer ID  Gender  Age Married  Number of Dependents          City  \
# 0     0002-ORFBO  Female   37     Yes                     0  Frazier Park
# 1     0003-MKNFE    Male   46      No                     0      Glendale
# 2     0004-TLHLJ    Male   50      No                     0    Costa Mesa
# 3     0011-IGKFF    Male   78     Yes                     0      Martinez
# 4     0013-EXCHZ  Female   75     Yes                     0     Camarillo
# ...          ...     ...  ...     ...                   ...           ...
# 7038  9987-LUTYD  Female   20      No                     0       La Mesa
# 7039  9992-RRAMN    Male   40     Yes                     0     Riverbank
# 7040  9992-UJOEL    Male   22      No                     0           Elk
# 7041  9993-LHIEB    Male   21     Yes                     0  Solana Beach
# 7042  9995-HOTOH    Male   36     Yes                     0   Sierra City
#
#       Zip Code   Latitude   Longitude  Number of Referrals  ...  \
# ...

# %%
Rduplicate = df.duplicated().sum()
print(f"Number of duplicate rows: {Rduplicate}")
# Out:
# Number of duplicate rows: 0

# %%
missingVal = df.isnull().sum().sum()
print(f"Missing value in DATA SET:,{missingVal}")
# Out:
# Missing value in DATA SET:,30849

# %%
print(df.isnull().sum())
# Out:
# Customer ID                             0
# Gender                                  0
# Age                                     0
# Married                                 0
# Number of Dependents                    0
# City                                    0
# Zip Code                                0
# Latitude                                0
# Longitude                               0
# Number of Referrals                     0
# Tenure in Months                        0
# Offer                                3877
# Phone Service                           0
# Avg Monthly Long Distance Charges     682
# Multiple Lines                        682
# Internet Service                        0
# Internet Type                        1526
# Avg Monthly GB Download              1526
# Online Security                      1526
# Online Backup                        1526
# Device Protection Plan               1526
# Premium Tech Support                 1526
# ...

# %%
df_cleaned = df.dropna()

# %%
print(df_cleaned)
# Out:
#      Customer ID  Gender  Age Married  Number of Dependents             City  \
# 2     0004-TLHLJ    Male   50      No                     0       Costa Mesa
# 3     0011-IGKFF    Male   78     Yes                     0         Martinez
# 54    0094-OIFMO  Female   78      No                     1  North Hollywood
# 67    0112-QWPNC    Male   61     Yes                     0         Valyermo
# 77    0125-LZQXK    Male   42      No                     0     Big Oak Flat
# ...          ...     ...  ...     ...                   ...              ...
# 7007  9940-RHLFB  Female   53      No                     0     Sunset Beach
# 7010  9944-HKVVB  Female   55      No                     0        King City
# 7012  9947-OTFQU    Male   65      No                     0           Covina
# 7036  9985-MWVIX  Female   53      No                     0             Hume
# 7039  9992-RRAMN    Male   40     Yes                     0        Riverbank
#
# ...

# %%
df_cleaned_columns = df.dropna(axis=1)

# %%
print(df_cleaned)
# Out:
#      Customer ID  Gender  Age Married  Number of Dependents             City  \
# 2     0004-TLHLJ    Male   50      No                     0       Costa Mesa
# 3     0011-IGKFF    Male   78     Yes                     0         Martinez
# 54    0094-OIFMO  Female   78      No                     1  North Hollywood
# 67    0112-QWPNC    Male   61     Yes                     0         Valyermo
# 77    0125-LZQXK    Male   42      No                     0     Big Oak Flat
# ...          ...     ...  ...     ...                   ...              ...
# 7007  9940-RHLFB  Female   53      No                     0     Sunset Beach
# 7010  9944-HKVVB  Female   55      No                     0        King City
# 7012  9947-OTFQU    Male   65      No                     0           Covina
# 7036  9985-MWVIX  Female   53      No                     0             Hume
# 7039  9992-RRAMN    Male   40     Yes                     0        Riverbank
#
# ...

# %%
df.describe()
# Out:
#                Age  Number of Dependents      Zip Code     Latitude  \
# count  7043.000000           7043.000000   7043.000000  7043.000000
# mean     46.509726              0.468692  93486.070567    36.197455
# std      16.750352              0.962802   1856.767505     2.468929
# min      19.000000              0.000000  90001.000000    32.555828
# 25%      32.000000              0.000000  92101.000000    33.990646
# 50%      46.000000              0.000000  93518.000000    36.205465
# 75%      60.000000              0.000000  95329.000000    38.161321
# max      80.000000              9.000000  96150.000000    41.962127
#
#          Longitude  Number of Referrals  Tenure in Months  \
# count  7043.000000          7043.000000       7043.000000
# mean   -119.756684             1.951867         32.386767
# std       2.154425             3.001199         24.542061
# min    -124.301372             0.000000          1.000000
# 25%    -121.788090             0.000000          9.000000
# ...

# %%
df = df[df['Monthly Charge'] >= 0]

# %%
df
# Out:
#      Customer ID  Gender  Age Married  Number of Dependents          City  \
# 0     0002-ORFBO  Female   37     Yes                     0  Frazier Park
# 2     0004-TLHLJ    Male   50      No                     0    Costa Mesa
# 3     0011-IGKFF    Male   78     Yes                     0      Martinez
# 4     0013-EXCHZ  Female   75     Yes                     0     Camarillo
# 5     0013-MHZWF  Female   23      No                     3      Midpines
# ...          ...     ...  ...     ...                   ...           ...
# 7038  9987-LUTYD  Female   20      No                     0       La Mesa
# 7039  9992-RRAMN    Male   40     Yes                     0     Riverbank
# 7040  9992-UJOEL    Male   22      No                     0           Elk
# 7041  9993-LHIEB    Male   21     Yes                     0  Solana Beach
# 7042  9995-HOTOH    Male   36     Yes                     0   Sierra City
#
#       Zip Code   Latitude   Longitude  Number of Referrals  ...  \
# ...

# %%
rowColumn = df.shape
print(f"Total number of rows and coloum: {rowColumn}")
# Out:
# Ttal number of rows and coloum: (6923, 38)

# %% [markdown]
# Before vs After Report
#
# | Feature        | Before Cleaning          | After Cleaning           |
# |----------------|--------------------------|--------------------------|
# | Shape          | (7043, 38)               | (6923, 38)               |
# | Missing Values | 3 columns had NaNs       | 0 columns have NaNs      |
# | Duplicates     | 0 duplicates             | 0 duplicates             |
# | Outliers       | Monthly Charge = -10     | Removed                  |
