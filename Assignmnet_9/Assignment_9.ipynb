# %% [markdown]
# #Week 9: Neural Networks Basics

# %% [markdown]
# An Artificial Neural Network is inspired by the human brain

# %% [markdown]
# CLASS TASK:
# 1. SIMPLE ANN
#
# Assignment 9:
#
# 1. Apply ANN on your dataset
# 2. Compare results with earlier models.

# %% [markdown]
# Step 1: Import Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# Step 2: Load & Prepare Data

# %%
df = pd.read_csv("telecom_customer_churn_final.csv")

# Encode target
le = LabelEncoder()
df['Customer Status'] = le.fit_transform(df['Customer Status'])

# Select numeric features only
X = df.select_dtypes(include=np.number).drop(columns=['Customer Status'])
y = df['Customer Status']

# %% [markdown]
# Step 3: Scale Data

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# Step 4: Train-Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# %% [markdown]
# Step 5: Build ANN Model

# %%
model = Sequential()

model.add(Dense(32, activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dense(16, activation='relu'))
model.add(Dense(3, activation='softmax'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# Step 6: Compile Model

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# Step 7: Train Model

# %%
model.fit(
    X_train, y_train,
    epochs=20,
    batch_size=32,
    validation_split=0.2
)
# Out:
# Epoch 1/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4734 - loss: 1.0478 - val_accuracy: 0.6866 - val_loss: 0.7418
# Epoch 2/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7236 - loss: 0.6906 - val_accuracy: 0.7166 - val_loss: 0.6505
# Epoch 3/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7456 - loss: 0.6094 - val_accuracy: 0.7226 - val_loss: 0.6261
# Epoch 4/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7479 - loss: 0.5904 - val_accuracy: 0.7285 - val_loss: 0.6098
# Epoch 5/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7567 - loss: 0.5739 - val_accuracy: 0.7206 - val_loss: 0.6044
# Epoch 6/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7746 - loss: 0.5329 - val_accuracy: 0.7226 - val_loss: 0.6012
# Epoch 7/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7569 - loss: 0.5613 - val_accuracy: 0.7285 - val_loss: 0.5952
# Epoch 8/20
# ...

# %% [markdown]
# Step 8: Evaluate

# %%
loss, acc = model.evaluate(X_test, y_test)
print("ANN Accuracy:", acc)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7658 - loss: 0.5349
# ANN Accuracy: 0.7571884989738464
